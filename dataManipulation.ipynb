# %%
import pandas
#https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_DEMO.htm
#https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_BMX.htm
#https://data.census.gov/table/ACSST1Y2022.S2001?q=American%20Community%20Survey%20Income%20by%20State%20and%20County

# %%
# Retrieve data sets
demodf_init = pandas.read_sas('data/P_DEMO.XPT')
measuredf_init = pandas.read_sas('data/P_BMX.XPT')
censusdf_init = pandas.read_csv('data/census.csv')
coldf_init = pandas.read_csv('data/column.csv')
measurements = pandas.read_csv('data/hw.csv')

# %%
measurements
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
# Format CDC data with relevant columns
dvars = ["RIAGENDR", "RIDAGEYR", "DMDMARTZ", "DMDEDUC2"]
demodf = demodf_init[dvars].copy()
mvars = ["BMXHT", "BMXWT"]
measuredf = measuredf_init[mvars].copy()

# %%
# Rename incomprehensible column names
mdf = measuredf.rename(columns={"BMXHT" : "Height(cm)", "BMXWT" : "Weight(kg)"}).copy()
ddf = demodf.rename(columns={"RIAGENDR" : "Gender", "RIDAGEYR" : "Age", 
                      "DMDMARTZ" : "Relationship", "DMDEDUC2": "Education"}).copy()
df = pandas.concat([ddf, mdf]).fillna(0)
df = df[(df['Weight(kg)'] != 0) & (df['Height(cm)'] != 0)]
df.head()
# Out:
#    Gender  Age  Relationship  Education  Height(cm)  Weight(kg)
# 1     0.0  0.0           0.0        0.0       154.7        42.2
# 2     0.0  0.0           0.0        0.0        89.3        12.0
# 3     0.0  0.0           0.0        0.0       160.2        97.1
# 5     0.0  0.0           0.0        0.0       156.0        75.3
# 6     0.0  0.0           0.0        0.0       182.3        98.8

# %%
# df.to_csv('cdc.csv', index=False)

# %%
cols = censusdf_init.columns
censusdf_init.columns
# Out:
# Index(['Label (Grouping)', 'Alabama!!Total!!Estimate',
#        'Alabama!!Total!!Margin of Error', 'Alabama!!Percent!!Estimate',
#        'Alabama!!Percent!!Margin of Error', 'Alabama!!Male!!Estimate',
#        'Alabama!!Male!!Margin of Error', 'Alabama!!Percent Male!!Estimate',
#        'Alabama!!Percent Male!!Margin of Error', 'Alabama!!Female!!Estimate',
#        ...
#        'Trujillo Alto Municipio, Puerto Rico!!Percent!!Estimate',
#        'Trujillo Alto Municipio, Puerto Rico!!Percent!!Margin of Error',
#        'Trujillo Alto Municipio, Puerto Rico!!Male!!Estimate',
#        'Trujillo Alto Municipio, Puerto Rico!!Male!!Margin of Error',
#        'Trujillo Alto Municipio, Puerto Rico!!Percent Male!!Estimate',
#        'Trujillo Alto Municipio, Puerto Rico!!Percent Male!!Margin of Error',
#        'Trujillo Alto Municipio, Puerto Rico!!Female!!Estimate',
#        'Trujillo Alto Municipio, Puerto Rico!!Female!!Margin of Error',
#        'Trujillo Alto Municipio, Puerto Rico!!Percent Female!!Estimate',
#        'Trujillo Alto Municipio, Puerto Rico!!Percent Female!!Margin of Error'],
#       dtype='object', length=10801)

# %%
# Gets rid of columns I do not care about
old_cols = [col for col in cols if "Error" not in col and "Puerto" not in col and
            "Percent" not in col and "County" not in col and "," not in col]
# Formats columns into more readable text
def removeEst(data):
    col_lst = []
    for title in data:
        if "Estimate" in title:
            col_lst.append(("_").join((("_").join(title.split("!!")[:-1])).split(" ")))
        else:
            col_lst.append(title)
    return col_lst
new_cols = removeEst(old_cols.copy())

# %%
# Renames columns to be more readable
def createMapping(old_cols, new_cols):
    mapping = {}
    for old, new in zip(old_cols, new_cols):
        mapping[old] = new
    return mapping
rename_cols = createMapping(old_cols, new_cols)

# %%
cens_renamed_df = censusdf_init[old_cols].rename(columns=rename_cols).fillna('0')

for col in cens_renamed_df.columns:
    if col != 'Label (Grouping)':
        cens_renamed_df[col] = cens_renamed_df[col].str.replace(',', '').astype(int)

# %%
cens_renamed_df
# Out:
#                                      Label (Grouping)  Alabama_Total  \
# 0          Population 16 years and over with earnings        2516192
# 1                           Median earnings (dollars)          36953
# 2         FULL-TIME, YEAR-ROUND WORKERS WITH EARNINGS        1723646
# 3                                $1 to $9,999 or loss          38226
# 4                                  $10,000 to $14,999          50954
# 5                                  $15,000 to $24,999         175399
# 6                                  $25,000 to $34,999         266047
# 7                                  $35,000 to $49,999         337591
# 8                                  $50,000 to $64,999         285446
# 9                                  $65,000 to $74,999         113486
# 10                                 $75,000 to $99,999         195029
# 11                                   $100,000 or more         261468
# 12          Median earnings (dollars) for full-tim...          49599
# 13          Mean earnings (dollars) for full-time,...          65475
# 14          MEDIAN EARNINGS BY EDUCATIONAL ATTAINMENT              0
# 15         Population 25 years and over with earnings          42463
# 16                     Less than high school graduate          28515
# 17          High school graduate (includes equival...          34127
# 18                 Some college or associate's degree          39501
# 19                                  Bachelor's degree          56640
# 20                    Graduate or professional degree          70732
#
#     Alabama_Male  Alabama_Female  Alaska_Total  Alaska_Male  Alaska_Female  \
# 0        1308524         1207668        407800       230522         177278
# 1          44443           30824         47357        53127          41567
# 2         964406          759240        255724       152785         102939
# 3          16913           21313          3189         2161           1028
# 4          21730           29224          4024         2498           1526
# 5          73921          101478         12662         7048           5614
# 6         124313          141734         29440        16218          13222
# 7         172012          165579         42610        22373          20237
# 8         160850          124596         44456        25261          19195
# 9          67461           46025         18865        11111           7754
# 10        129894           65135         42360        25199          17161
# 11        197312           64156         58118        40916          17202
# 12         55721           41951         62595        66109          57087
# 13         76010           52094         78850        82965          72742
# 14             0               0             0            0              0
# 15         51867           35268         53582        61327          47601
# 16         32089           22016         41145        44078          32000
# 17         41600           26337         40651        44861          32330
# 18         51002           31607         51499        59395          44106
# 19         71465           46955         67321        79622          56933
# 20         92889           60575         89202        97504          85703
#
#     Arizona_Total  Arizona_Male  Arizona_Female  ...  Washington_Female  \
# 0         3753211       2023859         1729352  ...            1948205
# 1           42346         47810           37718  ...              42221
# 2         2559331       1478889         1080442  ...            1141486
# 3           43204         22737           20467  ...              14763
# 4           48574         24377           24197  ...              19367
# 5          141666         71471           70195  ...              53817
# 6          332808        171777          161031  ...             116826
# 7          558630        296489          262141  ...             219023
# 8          463601        271231          192370  ...             185894
# 9          184668        104883           79785  ...              91423
# 10         310815        187565          123250  ...             171746
# 11         475365        328359          147006  ...             268627
# 12          53811         57628           50126  ...              61862
# 13          73903         81123           64020  ...              79748
# 14              0             0               0  ...                  0
# 15          48738         53647           42429  ...              49352
# 16          31966         36974           25764  ...              27512
# 17          38547         42457           32739  ...              35322
# 18          45115         51791           39821  ...              42451
# 19          63471         75517           53443  ...              61852
# 20          76587         95527           65877  ...              83186
#
#     West_Virginia_Total  West_Virginia_Male  West_Virginia_Female  \
# 0                810082              426516                383566
# 1                 37256               44476                 31364
# 2                548802              306208                242594
# 3                 10741                6093                  4648
# 4                 11228                5480                  5748
# 5                 53310               22293                 31017
# 6                 83668               37786                 45882
# 7                117635               56983                 60652
# 8                 97978               60192                 37786
# 9                 36441               20668                 15773
# 10                62537               41960                 20577
# 11                75264               54753                 20511
# 12                49650               54993                 42486
# 13                63396               69825                 55281
# 14                    0                   0                     0
# 15                42738               50775                 36638
# 16                26692               31728                 22346
# 17                35052               42328                 26556
# 18                40791               51797                 33565
# 19                52887               61978                 46408
# 20                63974               81142                 56531
#
#     Wisconsin_Total  Wisconsin_Male  Wisconsin_Female  Wyoming_Total  \
# 0           3308913         1742868           1566045         323741
# 1             42873           50488             36604          39954
# 2           2178536         1241897            936639         212802
# 3             33317           18571             14746           4278
# 4             33097           17852             15245           4208
# 5            108769           47133             61636          13379
# 6            245448          105751            139697          27557
# 7            481048          239222            241826          41671
# 8            437147          254618            182529          42548
# 9            192361          116724             75637          19466
# 10           292216          190207            102009          29234
# 11           355133          251819            103314          30461
# 12            55334           61280             49582          54398
# 13            72094           80588             60832          67805
# 14                0               0                 0              0
# 15            50039           56462             41920          48197
# 16            35193           39939             27810          28406
# 17            40104           46832             31059          37396
# 18            45726           54296             37815          44020
# 19            61428           74145             52799          54129
# 20            75811           93791             66703          68506
#
#     Wyoming_Male  Wyoming_Female
# 0         174588          149153
# 1          49839           32207
# 2         126510           86292
# 3           2144            2134
# 4           2069            2139
# 5           7467            5912
# 6          13936           13621
# 7          20785           20886
# 8          25073           17475
# 9          11557            7909
# 10         19496            9738
# 11         23983            6478
# 12         60412           47938
# 13         75807           56073
# 14             0               0
# 15         56879           38561
# 16         35274           25910
# 17         47300           27551
# 18         55153           36010
# 19         68407           47106
# 20         80346           61778
#
# [21 rows x 154 columns]

# %%
def findAmout(income):
    if income >= 100000:
        return 11
    elif income >= 75000:
        return 10
    elif income >= 65000:
        return 9
    elif income >= 50000:
        return 8
    elif income >= 35000:
        return 7
    elif income >= 25000:
        return 6
    elif income >= 15000:
        return 5
    elif income >= 10000:
        return 4
    else:
        return 3

# %%
# # Checking if we have correct amount of states
# states = []
# for col in cens_renamed_df.columns:
#     state = col.split("_")[0]
#     if state not in states:
#         states.append(state)
# states

# %%
# pandas.DataFrame(cens_renamed_df.iloc[1]).T.to_csv('revised_census.csv', index=False)

# %%
median = cens_renamed_df.iloc[1]
national_median = 37585

# %%
pandas.DataFrame(cens_renamed_df.iloc[1]).T
# Out:
#                 Label (Grouping) Alabama_Total Alabama_Male Alabama_Female  \
# 1      Median earnings (dollars)         36953        44443          30824
#
#   Alaska_Total Alaska_Male Alaska_Female Arizona_Total Arizona_Male  \
# 1        47357       53127         41567         42346        47810
#
#   Arizona_Female  ... Washington_Female West_Virginia_Total  \
# 1          37718  ...             42221               37256
#
#   West_Virginia_Male West_Virginia_Female Wisconsin_Total Wisconsin_Male  \
# 1              44476                31364           42873          50488
#
#   Wisconsin_Female Wyoming_Total Wyoming_Male Wyoming_Female
# 1            36604         39954        49839          32207
#
# [1 rows x 154 columns]
